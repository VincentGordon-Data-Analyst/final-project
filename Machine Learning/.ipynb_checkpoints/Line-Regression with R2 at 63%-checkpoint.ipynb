# %%
import numpy as np
import pandas as pd 
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("../Resources/housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df=df.ffill()

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df_y=df.drop(columns='median_house_value',axis=1)
df_y
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df_encoded = pd.get_dummies(df_y, columns=['ocean_proximity'])
df_encoded.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  ocean_proximity_<1H OCEAN  \
# 0       322.0       126.0         8.3252                          0
# 1      2401.0      1138.0         8.3014                          0
# 2       496.0       177.0         7.2574                          0
# 3       558.0       219.0         5.6431                          0
# 4       565.0       259.0         3.8462                          0
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# ...

# %%
df_data_scaled = StandardScaler().fit_transform(df_encoded)

# %%
df_data_scaled
# Out:
# array([[-1.32783522,  1.05254828,  0.98214266, ..., -0.01556621,
#          2.83074203, -0.38446649],
#        [-1.32284391,  1.04318455, -0.60701891, ..., -0.01556621,
#          2.83074203, -0.38446649],
#        [-1.33282653,  1.03850269,  1.85618152, ..., -0.01556621,
#          2.83074203, -0.38446649],
#        ...,
#        [-0.8237132 ,  1.77823747, -0.92485123, ..., -0.01556621,
#         -0.35326426, -0.38446649],
#        [-0.87362627,  1.77823747, -0.84539315, ..., -0.01556621,
#         -0.35326426, -0.38446649],
#        [-0.83369581,  1.75014627, -1.00430931, ..., -0.01556621,
#         -0.35326426, -0.38446649]])

# %%
df_encoded.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
df_data_scaled_transformed=pd.DataFrame(df_data_scaled,columns=df_encoded.columns)
df_data_scaled_transformed
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -1.327835  1.052548            0.982143    -0.804819       -0.970954
# 1      -1.322844  1.043185           -0.607019     2.045890        1.350447
# 2      -1.332827  1.038503            1.856182    -0.535746       -0.826015
# 3      -1.337818  1.038503            1.856182    -0.624215       -0.719093
# 4      -1.337818  1.038503            1.856182    -0.462404       -0.612171
# ...          ...       ...                 ...          ...             ...
# 20635  -0.758826  1.801647           -0.289187    -0.444985       -0.388822
# 20636  -0.818722  1.806329           -0.845393    -0.888704       -0.921057
# 20637  -0.823713  1.778237           -0.924851    -0.174995       -0.125080
# 20638  -0.873626  1.778237           -0.845393    -0.355600       -0.305660
# 20639  -0.833696  1.750146           -1.004309     0.068408        0.186182
#
# ...

# %%
# End of Data cleaning here

# %%
X=df_data_scaled_transformed
y=df['median_house_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1)

# %%
model1 = LinearRegression()

# %%
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
y_predict=model1.predict(X_test)

# %%
score = model1.score(X_test, y_test,sample_weight=None)

# %%
score
# Out:
# 0.6332533808000508

# %%
r2 = r2_score(y_test, y_predict)

# %%
r2
# Out:
# 0.6332533808000508
